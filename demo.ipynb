# %%
import time
import random
import argparse
from pathlib import Path
import numpy as np
import torch
import torchvision
from torchvision import transforms
from torch.backends import cudnn
from utils.dataloader_util import generate
from utils.train_util import load_model_pytorch, train, test
from nets.resnet_cifar import ResNet_CIFAR
from nets.vgg import VGG_CIFAR
import importlib
import logging
importlib.reload(logging)
logpath = ('./log/'+time.strftime("%m-%d %Hh%Mm%Ss", time.localtime())+'.log').replace('\\','/')
logging.basicConfig(
    filename=logpath,
    filemode='a',
    format='%(message)s',
    level=logging.INFO,
    datefmt='%H%M%S')

# %%
'''
全局配置
'''
# 工程目录
PROJECT_ROOT = "D:/code/federated-unlearning-via-class-discriminative-pruning"
# 数据源目录
DATA_ROOT = "D:/data"

# %%
#%%
'''
    Configuration
'''
parser = argparse.ArgumentParser(description='Training model')
parser.add_argument('--dataset', type=str, default='cifar10',
                    help='cifar10 or imagenet')
parser.add_argument('--dataroot', type=str, metavar=DATA_ROOT,
                    help='Path to Dataset folder')
parser.add_argument('--model', type=str, default='resnet56',
                    help='model to use, only resnet56, resnet20')
parser.add_argument('--pretrained', type=int, default=0,
                    help='whether to use pretrained model')
parser.add_argument('--batch_size', type=int, default=128,
                    help='input batch size for statistics (default: 128)')
parser.add_argument('--test_batch_size', type=int, default=256,
                    help='input batch size for testing (default: 256)')
parser.add_argument('--gpus', default='0', 
                    help='List of GPUs used for training - e.g 0,1,3')
parser.add_argument('--j', '--workers', default=8, type=int, metavar='N',
                    help='Number of data loading workers (default: 8)')
parser.add_argument('--seed', type=int, default=0, 
                    help='random seed (default: 0)')
parser.add_argument('--epochs', type=int, default=300,
                    help='epochs to train (default: 300)')
parser.add_argument('--lr', type=float, default=0.1,
                    help='learning rate to train (default: 0.1)')
parser.add_argument('--unlearn_class', type=int,
                    help='class label to unlearn')
parser.add_argument('--save_acc', type=float, default=94.0,
                    help='save accuracy')
parser.add_argument('--label_smoothing', type=float, default='0.0',
                    help='label smoothing rate')
parser.add_argument('--warmup_step', type=int, default='0',
                    help='warm up epochs')
parser.add_argument('--warm_lr', type=float, default='10e-5',
                    help='warm up learning rate')
# Out:
# _StoreAction(option_strings=['--warm_lr'], dest='warm_lr', nargs=None, const=None, default='10e-5', type=<class 'float'>, choices=None, required=False, help='warm up learning rate', metavar=None)

# %%
def setup_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     torch.cuda.manual_seed(seed)
     np.random.seed(seed)
     random.seed(seed)
     cudnn.deterministic = True


def Retraining():
    '''configuration'''
    args = parser.parse_args()
    args.dataset = 'cifar10'
    project_dir = PROJECT_ROOT
    args.dataroot = DATA_ROOT
    args.model = 'resnet20'
    args.pretrained = 0
    args.unlearn_class = 9
    args.gpus = "0"
    args.j = 4
    args.epochs = 100
    args.lr = 0.1
    args.save_acc = 0.0
    args.label_smoothing = 0.0 
    args.warmup_step = 0
    args.warm_lr = 10e-5
    print(args)
    
    setup_seed(args.seed)
    save_info = project_dir + '/' + 'ckpt' + '/' + 'retrained' + '/' + args.model  
    
    if args.dataset == 'cifar10':
        '''load data and model'''
        mean=[125.31 / 255, 122.95 / 255, 113.87 / 255]
        std=[63.0 / 255, 62.09 / 255, 66.70 / 255]
        transform_train = transforms.Compose([
            transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize(mean, std),
            ])
        transform_test = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean,std)
            ])
        total_classes = 10 # [0-9]
        trainset = torchvision.datasets.CIFAR10(root=DATA_ROOT, train=True, download=False, transform=transform_train)
        testset = torchvision.datasets.CIFAR10(root=DATA_ROOT, train=False, download=False, transform=transform_test)

        if args.model == 'resnet56':
            net = ResNet_CIFAR(depth=56, num_classes=10)
        elif args.model == 'resnet20':
            net = ResNet_CIFAR(depth=20, num_classes=10)
        elif args.model == 'vgg':
            net = VGG_CIFAR(num_classes=10)
        else:
            print('no model')
        net = net.cuda()
        if args.pretrained == 1:
            model_path = project_dir + '/' + 'ckpt' + '/' + 'retrained' + '/' + args.model + '/' + 'seed_0_acc_49.65.pth'
            load_model_pytorch(net, model_path, args.model)

    list_allclasses = list(range(total_classes))
    unlearn_listclass = [args.unlearn_class]
    list_allclasses.remove(args.unlearn_class) # rest classes
    rest_traindata = generate(trainset, list_allclasses)
    rest_testdata = generate(testset, list_allclasses)
    unlearn_testdata = generate(testset, unlearn_listclass)
    print(len(rest_traindata), len(rest_testdata), len(unlearn_testdata))
    rest_trainloader = torch.utils.data.DataLoader(rest_traindata, batch_size=args.batch_size, 
                                                   shuffle=False, num_workers=4)
    rest_testloader = torch.utils.data.DataLoader(rest_testdata, batch_size=args.test_batch_size, 
                                                  shuffle=False, num_workers=4)
    unlearn_testloader = torch.utils.data.DataLoader(unlearn_testdata, batch_size=args.test_batch_size, 
                                                  shuffle=False, num_workers=4)
    
    '''training''' 
    train(net, epochs=args.epochs, lr=args.lr, train_loader=rest_trainloader, 
          test_loader=rest_testloader, save_info=save_info, save_acc=args.save_acc, seed=args.seed,
          label_smoothing=args.label_smoothing, warmup_step=args.warmup_step, warm_lr=args.warm_lr)

    print('*'*5+'testing in unlearn_data'+'*'*12)
    test(net, unlearn_testloader)
    print('*'*40)

    print('finished')

# %%
import sys
sys.argv = ['run.py']
Retraining()
# Out:
# Namespace(dataset='cifar10', dataroot='D:/data', model='resnet20', pretrained=0, batch_size=128, test_batch_size=256, gpus='0', j=4, seed=0, epochs=100, lr=0.1, unlearn_class=9, save_acc=0.0, label_smoothing=0.0, warmup_step=0, warm_lr=0.0001)
# 45000 9000 1000
# label smoothing: 0.0
#
# Epoch: 0 / 100; learning_rate: 0.1
# Train Loss=1.63750352, Train acc=0.37733333
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc47.69_epoch0_2024-01-22 14-06-10.pth
# Test Loss=1.48869777, Test acc=0.47700000
#
# Epoch: 1 / 100; learning_rate: 0.09997532801828658
# Train Loss=1.28460621, Train acc=0.52726667
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc54.45_epoch1_2024-01-22 14-07-12.pth
# Test Loss=1.37078313, Test acc=0.54455556
#
# Epoch: 2 / 100; learning_rate: 0.09990133642141358
# Train Loss=1.11702288, Train acc=0.59386667
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc65.0_epoch2_2024-01-22 14-08-14.pth
# Test Loss=1.00727721, Test acc=0.65000000
#
# Epoch: 3 / 100; learning_rate: 0.099778098230154
# Train Loss=1.00415525, Train acc=0.63891111
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc66.01_epoch3_2024-01-22 14-09-17.pth
# Test Loss=1.00759306, Test acc=0.66011111
#
# Epoch: 4 / 100; learning_rate: 0.0996057350657239
# Train Loss=0.92118360, Train acc=0.67077778
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc67.48_epoch4_2024-01-22 14-10-19.pth
# Test Loss=1.04593062, Test acc=0.67488889
#
# Epoch: 5 / 100; learning_rate: 0.09938441702975688
# Train Loss=0.85479839, Train acc=0.69564444
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc67.27_epoch5_2024-01-22 14-11-23.pth
# Test Loss=1.06129974, Test acc=0.67277778
#
# Epoch: 6 / 100; learning_rate: 0.09911436253643444
# Train Loss=0.80962793, Train acc=0.71137778
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc67.76_epoch6_2024-01-22 14-12-26.pth
# Test Loss=1.03820296, Test acc=0.67766667
#
# Epoch: 7 / 100; learning_rate: 0.09879583809693737
# Train Loss=0.77233324, Train acc=0.72795556
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc71.12_epoch7_2024-01-22 14-13-26.pth
# Test Loss=0.87065174, Test acc=0.71122222
#
# Epoch: 8 / 100; learning_rate: 0.09842915805643156
# Train Loss=0.74487060, Train acc=0.73862222
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc71.97_epoch8_2024-01-22 14-14-31.pth
# Test Loss=0.89837168, Test acc=0.71977778
#
# Epoch: 9 / 100; learning_rate: 0.09801468428384716
# Train Loss=0.71978248, Train acc=0.74544444
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc62.95_epoch9_2024-01-22 14-15-47.pth
# Test Loss=1.47353268, Test acc=0.62955556
#
# Epoch: 10 / 100; learning_rate: 0.09755282581475769
# Train Loss=0.69997159, Train acc=0.75433333
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc71.76_epoch10_2024-01-22 14-16-50.pth
# Test Loss=0.90504577, Test acc=0.71766667
#
# Epoch: 11 / 100; learning_rate: 0.09704403844771128
# Train Loss=0.67982716, Train acc=0.76097778
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc67.14_epoch11_2024-01-22 14-17-54.pth
# Test Loss=1.06103701, Test acc=0.67144444
#
# Epoch: 12 / 100; learning_rate: 0.09648882429441258
# Train Loss=0.66871620, Train acc=0.76591111
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc69.35_epoch12_2024-01-22 14-18-57.pth
# Test Loss=1.02294266, Test acc=0.69355556
#
# Epoch: 13 / 100; learning_rate: 0.09588773128419906
# Train Loss=0.65611684, Train acc=0.76795556
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc73.18_epoch13_2024-01-22 14-20-01.pth
# Test Loss=0.88902219, Test acc=0.73188889
#
# Epoch: 14 / 100; learning_rate: 0.09524135262330098
# Train Loss=0.64768660, Train acc=0.77304444
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc78.53_epoch14_2024-01-22 14-21-09.pth
# Test Loss=0.65824757, Test acc=0.78533333
#
# Epoch: 15 / 100; learning_rate: 0.0945503262094184
# Train Loss=0.63106811, Train acc=0.77942222
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc70.06_epoch15_2024-01-22 14-22-16.pth
# Test Loss=0.97405520, Test acc=0.70066667
#
# Epoch: 16 / 100; learning_rate: 0.09381533400219319
# Train Loss=0.61862705, Train acc=0.78306667
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc62.98_epoch16_2024-01-22 14-23-23.pth
# Test Loss=1.47944463, Test acc=0.62988889
#
# Epoch: 17 / 100; learning_rate: 0.0930371013501972
# Train Loss=0.61498597, Train acc=0.78346667
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc75.42_epoch17_2024-01-22 14-24-29.pth
# Test Loss=0.80856575, Test acc=0.75422222
#
# Epoch: 18 / 100; learning_rate: 0.09221639627510078
# Train Loss=0.60537738, Train acc=0.78913333
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc69.3_epoch18_2024-01-22 14-25-35.pth
# Test Loss=1.12637459, Test acc=0.69300000
#
# Epoch: 19 / 100; learning_rate: 0.09135402871372812
# Train Loss=0.59328051, Train acc=0.79142222
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc74.68_epoch19_2024-01-22 14-26-40.pth
# Test Loss=0.80851673, Test acc=0.74688889
#
# Epoch: 20 / 100; learning_rate: 0.09045084971874741
# Train Loss=0.58735472, Train acc=0.79393333
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc71.93_epoch20_2024-01-22 14-27-44.pth
# Test Loss=0.93813830, Test acc=0.71933333
#
# Epoch: 21 / 100; learning_rate: 0.08950775061878455
# Train Loss=0.58540475, Train acc=0.79537778
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc76.68_epoch21_2024-01-22 14-28-47.pth
# Test Loss=0.80053084, Test acc=0.76688889
#
# Epoch: 22 / 100; learning_rate: 0.08852566213878948
# Train Loss=0.58244893, Train acc=0.79504444
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc71.28_epoch22_2024-01-22 14-29-50.pth
# Test Loss=0.99980221, Test acc=0.71288889
#
# Epoch: 23 / 100; learning_rate: 0.087505553481523
# Train Loss=0.56999934, Train acc=0.80026667
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc70.39_epoch23_2024-01-22 14-30-54.pth
# Test Loss=0.99378902, Test acc=0.70400000
#
# Epoch: 24 / 100; learning_rate: 0.0864484313710706
# Train Loss=0.56690388, Train acc=0.80004444
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc76.21_epoch24_2024-01-22 14-32-00.pth
# Test Loss=0.81663749, Test acc=0.76211111
#
# Epoch: 25 / 100; learning_rate: 0.08535533905932739
# Train Loss=0.55725443, Train acc=0.80337778
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc74.96_epoch25_2024-01-22 14-33-04.pth
# Test Loss=0.88886498, Test acc=0.74966667
#
# Epoch: 26 / 100; learning_rate: 0.08422735529643445
# Train Loss=0.55735732, Train acc=0.80346667
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc78.63_epoch26_2024-01-22 14-34-07.pth
# Test Loss=0.69974662, Test acc=0.78633333
#
# Epoch: 27 / 100; learning_rate: 0.08306559326618261
# Train Loss=0.54755783, Train acc=0.80733333
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc73.97_epoch27_2024-01-22 14-35-11.pth
# Test Loss=0.84504948, Test acc=0.73977778
#
# Epoch: 28 / 100; learning_rate: 0.0818711994874345
# Train Loss=0.54617198, Train acc=0.80597778
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc75.01_epoch28_2024-01-22 14-36-15.pth
# Test Loss=0.81822108, Test acc=0.75011111
#
# Epoch: 29 / 100; learning_rate: 0.08064535268264884
# Train Loss=0.53930138, Train acc=0.81166667
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc78.01_epoch29_2024-01-22 14-37-19.pth
# Test Loss=0.74381500, Test acc=0.78011111
#
# Epoch: 30 / 100; learning_rate: 0.07938926261462369
# Train Loss=0.52344824, Train acc=0.81571111
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc77.03_epoch30_2024-01-22 14-38-23.pth
# Test Loss=0.74682607, Test acc=0.77033333
#
# Epoch: 31 / 100; learning_rate: 0.07810416889260656
# Train Loss=0.51689535, Train acc=0.81675556
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc77.92_epoch31_2024-01-22 14-39-27.pth
# Test Loss=0.75719936, Test acc=0.77922222
#
# Epoch: 32 / 100; learning_rate: 0.07679133974894985
# Train Loss=0.52033627, Train acc=0.81655556
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc76.34_epoch32_2024-01-22 14-40-31.pth
# Test Loss=0.80958832, Test acc=0.76344444
#
# Epoch: 33 / 100; learning_rate: 0.07545207078751859
# Train Loss=0.51889867, Train acc=0.81746667
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc78.7_epoch33_2024-01-22 14-41-35.pth
# Test Loss=0.72010263, Test acc=0.78700000
#
# Epoch: 34 / 100; learning_rate: 0.07408768370508578
# Train Loss=0.50815013, Train acc=0.82228889
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc75.06_epoch34_2024-01-22 14-42-39.pth
# Test Loss=0.78207509, Test acc=0.75066667
#
# Epoch: 35 / 100; learning_rate: 0.07269952498697736
# Train Loss=0.49641401, Train acc=0.82464444
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc76.23_epoch35_2024-01-22 14-43-43.pth
# Test Loss=0.81695923, Test acc=0.76233333
#
# Epoch: 36 / 100; learning_rate: 0.07128896457825365
# Train Loss=0.49599885, Train acc=0.82633333
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc78.92_epoch36_2024-01-22 14-44-47.pth
# Test Loss=0.69066725, Test acc=0.78922222
#
# Epoch: 37 / 100; learning_rate: 0.06985739453173904
# Train Loss=0.49000291, Train acc=0.82835556
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc78.71_epoch37_2024-01-22 14-45-51.pth
# Test Loss=0.66767759, Test acc=0.78711111
#
# Epoch: 38 / 100; learning_rate: 0.06840622763423393
# Train Loss=0.48313150, Train acc=0.82957778
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc74.94_epoch38_2024-01-22 14-46-55.pth
# Test Loss=0.89201904, Test acc=0.74944444
#
# Epoch: 39 / 100; learning_rate: 0.0669368960122646
# Train Loss=0.47773528, Train acc=0.83055556
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc78.93_epoch39_2024-01-22 14-47-59.pth
# Test Loss=0.69546830, Test acc=0.78933333
#
# Epoch: 40 / 100; learning_rate: 0.0654508497187474
# Train Loss=0.46963240, Train acc=0.83484444
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc79.68_epoch40_2024-01-22 14-49-02.pth
# Test Loss=0.61122519, Test acc=0.79688889
#
# Epoch: 41 / 100; learning_rate: 0.0639495553019615
# Train Loss=0.46688810, Train acc=0.83606667
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc78.31_epoch41_2024-01-22 14-50-06.pth
# Test Loss=0.72914056, Test acc=0.78311111
#
# Epoch: 42 / 100; learning_rate: 0.06243449435824276
# Train Loss=0.46451843, Train acc=0.83684444
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc75.7_epoch42_2024-01-22 14-51-11.pth
# Test Loss=0.88652468, Test acc=0.75700000
#
# Epoch: 43 / 100; learning_rate: 0.060907162069827166
# Train Loss=0.45588831, Train acc=0.84051111
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc79.66_epoch43_2024-01-22 14-52-12.pth
# Test Loss=0.68481232, Test acc=0.79666667
#
# Epoch: 44 / 100; learning_rate: 0.059369065729286276
# Train Loss=0.44627686, Train acc=0.84404444
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc73.76_epoch44_2024-01-22 14-53-12.pth
# Test Loss=0.92906595, Test acc=0.73766667
#
# Epoch: 45 / 100; learning_rate: 0.057821723252011584
# Train Loss=0.44691263, Train acc=0.84380000
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc79.82_epoch45_2024-01-22 14-54-12.pth
# Test Loss=0.64745695, Test acc=0.79822222
#
# Epoch: 46 / 100; learning_rate: 0.05626666167821526
# Train Loss=0.43287966, Train acc=0.84686667
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc76.42_epoch46_2024-01-22 14-55-12.pth
# Test Loss=0.85601694, Test acc=0.76422222
#
# Epoch: 47 / 100; learning_rate: 0.054705415665925745
# Train Loss=0.43103661, Train acc=0.84764444
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc77.35_epoch47_2024-01-22 14-56-12.pth
# Test Loss=0.84085640, Test acc=0.77355556
#
# Epoch: 48 / 100; learning_rate: 0.05313952597646571
# Train Loss=0.42293722, Train acc=0.85166667
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc79.55_epoch48_2024-01-22 14-57-12.pth
# Test Loss=0.64453606, Test acc=0.79555556
#
# Epoch: 49 / 100; learning_rate: 0.051570537953906447
# Train Loss=0.42152872, Train acc=0.85095556
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc75.12_epoch49_2024-01-22 14-58-13.pth
# Test Loss=0.94668061, Test acc=0.75122222
#
# Epoch: 50 / 100; learning_rate: 0.05000000000000003
# Train Loss=0.41087306, Train acc=0.85566667
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc83.04_epoch50_2024-01-22 14-59-13.pth
# Test Loss=0.55452828, Test acc=0.83044444
#
# Epoch: 51 / 100; learning_rate: 0.048429462046093615
# Train Loss=0.40105944, Train acc=0.85802222
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc80.13_epoch51_2024-01-22 15-00-14.pth
# Test Loss=0.71597257, Test acc=0.80133333
#
# Epoch: 52 / 100; learning_rate: 0.04686047402353436
# Train Loss=0.39601266, Train acc=0.86062222
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc78.37_epoch52_2024-01-22 15-01-15.pth
# Test Loss=0.78838468, Test acc=0.78377778
#
# Epoch: 53 / 100; learning_rate: 0.04529458433407431
# Train Loss=0.39248817, Train acc=0.86073333
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc81.03_epoch53_2024-01-22 15-02-15.pth
# Test Loss=0.66079835, Test acc=0.81033333
#
# Epoch: 54 / 100; learning_rate: 0.04373333832178482
# Train Loss=0.38565189, Train acc=0.86311111
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc77.75_epoch54_2024-01-22 15-03-15.pth
# Test Loss=0.85268134, Test acc=0.77755556
#
# Epoch: 55 / 100; learning_rate: 0.04217827674798848
# Train Loss=0.37651345, Train acc=0.86657778
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc81.44_epoch55_2024-01-22 15-04-16.pth
# Test Loss=0.65857693, Test acc=0.81444444
#
# Epoch: 56 / 100; learning_rate: 0.04063093427071379
# Train Loss=0.36599303, Train acc=0.87200000
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc81.67_epoch56_2024-01-22 15-05-16.pth
# Test Loss=0.61257281, Test acc=0.81677778
#
# Epoch: 57 / 100; learning_rate: 0.03909283793017291
# Train Loss=0.35330729, Train acc=0.87608889
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc81.63_epoch57_2024-01-22 15-06-17.pth
# Test Loss=0.60390900, Test acc=0.81633333
#
# Epoch: 58 / 100; learning_rate: 0.03756550564175728
# Train Loss=0.35201458, Train acc=0.87564444
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc78.45_epoch58_2024-01-22 15-07-17.pth
# Test Loss=0.80105178, Test acc=0.78455556
#
# Epoch: 59 / 100; learning_rate: 0.036050444698038565
# Train Loss=0.33752737, Train acc=0.88026667
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc81.69_epoch59_2024-01-22 15-08-18.pth
# Test Loss=0.67490560, Test acc=0.81700000
#
# Epoch: 60 / 100; learning_rate: 0.03454915028125267
# Train Loss=0.33242110, Train acc=0.88337778
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc81.56_epoch60_2024-01-22 15-09-18.pth
# Test Loss=0.65327973, Test acc=0.81566667
#
# Epoch: 61 / 100; learning_rate: 0.03306310398773545
# Train Loss=0.32565283, Train acc=0.88548889
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc82.82_epoch61_2024-01-22 15-10-18.pth
# Test Loss=0.63208573, Test acc=0.82822222
#
# Epoch: 62 / 100; learning_rate: 0.03159377236576614
# Train Loss=0.31679403, Train acc=0.88751111
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc82.84_epoch62_2024-01-22 15-11-18.pth
# Test Loss=0.57353863, Test acc=0.82844444
#
# Epoch: 63 / 100; learning_rate: 0.030142605468260985
# Train Loss=0.31144667, Train acc=0.89051111
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc84.04_epoch63_2024-01-22 15-12-18.pth
# Test Loss=0.54924766, Test acc=0.84044444
#
# Epoch: 64 / 100; learning_rate: 0.028711035421746387
# Train Loss=0.30223172, Train acc=0.89451111
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc82.67_epoch64_2024-01-22 15-13-18.pth
# Test Loss=0.62053873, Test acc=0.82677778
#
# Epoch: 65 / 100; learning_rate: 0.02730047501302268
# Train Loss=0.29157443, Train acc=0.89715556
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc82.84_epoch65_2024-01-22 15-14-18.pth
# Test Loss=0.58671281, Test acc=0.82844444
#
# Epoch: 66 / 100; learning_rate: 0.025912316294914247
# Train Loss=0.27896273, Train acc=0.90171111
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc84.57_epoch66_2024-01-22 15-15-18.pth
# Test Loss=0.56138767, Test acc=0.84577778
#
# Epoch: 67 / 100; learning_rate: 0.024547929212481452
# Train Loss=0.27229075, Train acc=0.90508889
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc84.94_epoch67_2024-01-22 15-16-19.pth
# Test Loss=0.54288124, Test acc=0.84944444
#
# Epoch: 68 / 100; learning_rate: 0.023208660251050173
# Train Loss=0.25507550, Train acc=0.91128889
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc82.11_epoch68_2024-01-22 15-17-19.pth
# Test Loss=0.65976681, Test acc=0.82111111
#
# Epoch: 69 / 100; learning_rate: 0.02189583110739348
# Train Loss=0.24977121, Train acc=0.91188889
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc83.72_epoch69_2024-01-22 15-18-19.pth
# Test Loss=0.60289933, Test acc=0.83722222
#
# Epoch: 70 / 100; learning_rate: 0.020610737385376363
# Train Loss=0.24843105, Train acc=0.91377778
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc84.41_epoch70_2024-01-22 15-19-19.pth
# Test Loss=0.56675941, Test acc=0.84411111
#
# Epoch: 71 / 100; learning_rate: 0.019354647317351183
# Train Loss=0.23674564, Train acc=0.91731111
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc84.37_epoch71_2024-01-22 15-20-19.pth
# Test Loss=0.53658898, Test acc=0.84377778
#
# Epoch: 72 / 100; learning_rate: 0.018128800512565525
# Train Loss=0.22237669, Train acc=0.92117778
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc83.81_epoch72_2024-01-22 15-21-19.pth
# Test Loss=0.60241238, Test acc=0.83811111
#
# Epoch: 73 / 100; learning_rate: 0.016934406733817426
# Train Loss=0.21649640, Train acc=0.92366667
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc81.47_epoch73_2024-01-22 15-22-20.pth
# Test Loss=0.72494677, Test acc=0.81477778
#
# Epoch: 74 / 100; learning_rate: 0.015772644703565576
# Train Loss=0.20260334, Train acc=0.92928889
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc85.06_epoch74_2024-01-22 15-23-20.pth
# Test Loss=0.52771922, Test acc=0.85066667
#
# Epoch: 75 / 100; learning_rate: 0.014644660940672639
# Train Loss=0.19278032, Train acc=0.93355556
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc85.44_epoch75_2024-01-22 15-24-20.pth
# Test Loss=0.52982472, Test acc=0.85444444
#
# Epoch: 76 / 100; learning_rate: 0.013551568628929445
# Train Loss=0.18328502, Train acc=0.93691111
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc85.16_epoch76_2024-01-22 15-25-20.pth
# Test Loss=0.56208783, Test acc=0.85166667
#
# Epoch: 77 / 100; learning_rate: 0.012494446518477037
# Train Loss=0.18051377, Train acc=0.93744444
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc85.45_epoch77_2024-01-22 15-26-20.pth
# Test Loss=0.53399961, Test acc=0.85455556
#
# Epoch: 78 / 100; learning_rate: 0.011474337861210554
# Train Loss=0.16335593, Train acc=0.94466667
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc85.46_epoch78_2024-01-22 15-27-21.pth
# Test Loss=0.52541918, Test acc=0.85466667
#
# Epoch: 79 / 100; learning_rate: 0.01049224938121549
# Train Loss=0.15621437, Train acc=0.94640000
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc85.91_epoch79_2024-01-22 15-28-21.pth
# Test Loss=0.51907012, Test acc=0.85911111
#
# Epoch: 80 / 100; learning_rate: 0.009549150281252642
# Train Loss=0.14617626, Train acc=0.95042222
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc85.48_epoch80_2024-01-22 15-29-21.pth
# Test Loss=0.54305457, Test acc=0.85488889
#
# Epoch: 81 / 100; learning_rate: 0.008645971286271927
# Train Loss=0.13488054, Train acc=0.95448889
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc86.77_epoch81_2024-01-22 15-30-21.pth
# Test Loss=0.47156319, Test acc=0.86777778
#
# Epoch: 82 / 100; learning_rate: 0.007783603724899264
# Train Loss=0.12600625, Train acc=0.95873333
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc86.57_epoch82_2024-01-22 15-31-21.pth
# Test Loss=0.52025924, Test acc=0.86577778
#
# Epoch: 83 / 100; learning_rate: 0.006962898649802819
# Train Loss=0.11425355, Train acc=0.96262222
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc86.85_epoch83_2024-01-22 15-32-21.pth
# Test Loss=0.51371496, Test acc=0.86855556
#
# Epoch: 84 / 100; learning_rate: 0.0061846659978068265
# Train Loss=0.11403002, Train acc=0.96300000
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc86.7_epoch84_2024-01-22 15-33-22.pth
# Test Loss=0.51162258, Test acc=0.86700000
#
# Epoch: 85 / 100; learning_rate: 0.005449673790581615
# Train Loss=0.10426894, Train acc=0.96633333
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc86.92_epoch85_2024-01-22 15-34-23.pth
# Test Loss=0.49554939, Test acc=0.86922222
#
# Epoch: 86 / 100; learning_rate: 0.004758647376699036
# Train Loss=0.10101854, Train acc=0.96713333
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc87.08_epoch86_2024-01-22 15-35-22.pth
# Test Loss=0.49873794, Test acc=0.87088889
#
# Epoch: 87 / 100; learning_rate: 0.004112268715800957
# Train Loss=0.09079806, Train acc=0.97064444
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc87.0_epoch87_2024-01-22 15-36-22.pth
# Test Loss=0.48214252, Test acc=0.87000000
#
# Epoch: 88 / 100; learning_rate: 0.003511175705587435
# Train Loss=0.08707348, Train acc=0.97155556
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc87.32_epoch88_2024-01-22 15-37-22.pth
# Test Loss=0.48208013, Test acc=0.87322222
#
# Epoch: 89 / 100; learning_rate: 0.0029559615522887295
# Train Loss=0.08478804, Train acc=0.97295556
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc87.32_epoch89_2024-01-22 15-38-22.pth
# Test Loss=0.49081265, Test acc=0.87322222
#
# Epoch: 90 / 100; learning_rate: 0.0024471741852423253
# Train Loss=0.07935004, Train acc=0.97508889
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc87.48_epoch90_2024-01-22 15-39-22.pth
# Test Loss=0.47719106, Test acc=0.87488889
#
# Epoch: 91 / 100; learning_rate: 0.0019853157161528537
# Train Loss=0.07327252, Train acc=0.97740000
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc87.38_epoch91_2024-01-22 15-40-23.pth
# Test Loss=0.48011474, Test acc=0.87388889
#
# Epoch: 92 / 100; learning_rate: 0.0015708419435684529
# Train Loss=0.07160880, Train acc=0.97788889
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc87.62_epoch92_2024-01-22 15-41-23.pth
# Test Loss=0.47392224, Test acc=0.87622222
#
# Epoch: 93 / 100; learning_rate: 0.0012041619030626347
# Train Loss=0.06947559, Train acc=0.97842222
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc87.72_epoch93_2024-01-22 15-42-23.pth
# Test Loss=0.46368118, Test acc=0.87722222
#
# Epoch: 94 / 100; learning_rate: 0.0008856374635655646
# Train Loss=0.06570114, Train acc=0.97997778
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc87.71_epoch94_2024-01-22 15-43-23.pth
# Test Loss=0.46572723, Test acc=0.87711111
#
# Epoch: 95 / 100; learning_rate: 0.0006155829702431174
# Train Loss=0.06501181, Train acc=0.98073333
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc87.66_epoch95_2024-01-22 15-44-23.pth
# Test Loss=0.46924663, Test acc=0.87666667
#
# Epoch: 96 / 100; learning_rate: 0.00039426493427611206
# Train Loss=0.06344039, Train acc=0.98068889
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc87.81_epoch96_2024-01-22 15-45-23.pth
# Test Loss=0.46690902, Test acc=0.87811111
#
# Epoch: 97 / 100; learning_rate: 0.00022190176984600036
# Train Loss=0.06172422, Train acc=0.98140000
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc87.91_epoch97_2024-01-22 15-46-24.pth
# Test Loss=0.46445915, Test acc=0.87911111
#
# Epoch: 98 / 100; learning_rate: 9.866357858642213e-05
# Train Loss=0.06063221, Train acc=0.98142222
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc87.92_epoch98_2024-01-22 15-47-24.pth
# Test Loss=0.46365453, Test acc=0.87922222
#
# Epoch: 99 / 100; learning_rate: 2.4671981713420017e-05
# Train Loss=0.06212727, Train acc=0.98108889
# save path D:/code/federated-unlearning-via-class-discriminative-pruning/ckpt/retrained/resnet20/seed0_acc87.94_epoch99_2024-01-22 15-48-24.pth
# Test Loss=0.46199763, Test acc=0.87944444
# *****testing in unlearn_data************
# Test Loss=13.9048, Test accuracy=0.0000
# ****************************************
# finished

# %%
# mean=[125.31 / 255, 122.95 / 255, 113.87 / 255]
# std=[63.0 / 255, 62.09 / 255, 66.70 / 255]
# transform_train = transforms.Compose([
#     transforms.RandomCrop(32, padding=4),
#     transforms.RandomHorizontalFlip(),
#     transforms.ToTensor(),
#     transforms.Normalize(mean, std),
#     ])
# transform_test = transforms.Compose([
#     transforms.ToTensor(),
#     transforms.Normalize(mean,std)
#     ])
# trainset = torchvision.datasets.CIFAR10(root=DATA_ROOT, train=True, download=True, transform=transform_train)
# testset = torchvision.datasets.CIFAR10(root=DATA_ROOT, train=False, download=True, transform=transform_test)
